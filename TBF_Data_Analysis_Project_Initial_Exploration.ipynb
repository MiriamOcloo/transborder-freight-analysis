# %% [markdown]
# <a href="https://colab.research.google.com/github/MiriamOcloo/transborder-freight-analysis/blob/main/TBF_Data_Analysis_Project_Initial_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/BTS_Freight_Sample/sample_file.csv'
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (24384, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24384 entries, 0 to 24383
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TRDTYPE          24384 non-null  int64
#  1   USASTATE         24384 non-null  object
#  2   DEPE             24384 non-null  object
#  3   DISAGMOT         24384 non-null  int64
#  4   MEXSTATE         6761 non-null   object
#  5   CANPROV          15743 non-null  object
#  6   COUNTRY          24384 non-null  int64
#  7   VALUE            24384 non-null  int64
#  8   SHIPWT           24384 non-null  int64
#  9   FREIGHT_CHARGES  24384 non-null  int64
#  10  DF               14979 non-null  float64
#  11  CONTCODE         24384 non-null  object
#  12  MONTH            24384 non-null  int64
#  13  YEAR             24384 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#             TRDTYPE      DISAGMOT       COUNTRY         VALUE        SHIPWT  \
# count  24384.000000  24384.000000  24384.000000  2.438400e+04  2.438400e+04
# mean       1.385704      4.798926   1499.953658  2.383652e+06  1.802506e+06
# std        0.486771      1.389539    377.882515  2.257811e+07  4.762363e+07
# min        1.000000      1.000000   1220.000000  0.000000e+00  0.000000e+00
# 25%        1.000000      5.000000   1220.000000  1.827875e+04  0.000000e+00
# 50%        1.000000      5.000000   1220.000000  8.593800e+04  7.000000e+00
# 75%        2.000000      5.000000   2010.000000  4.981165e+05  1.410150e+04
# max        2.000000      9.000000   2010.000000  1.662953e+09  6.189504e+09
#
#        FREIGHT_CHARGES            DF    MONTH     YEAR
# count     2.438400e+04  14979.000000  24384.0  24384.0
# mean      4.317150e+04      1.321450      4.0   2020.0
# std       9.727106e+05      0.467049      0.0      0.0
# min       0.000000e+00      1.000000      4.0   2020.0
# ...

# %%
df.isnull().sum()
# Out:
# TRDTYPE                0
# USASTATE               0
# DEPE                   0
# DISAGMOT               0
# MEXSTATE           17623
# CANPROV             8641
# COUNTRY                0
# VALUE                  0
# SHIPWT                 0
# FREIGHT_CHARGES        0
# DF                  9405
# CONTCODE               0
# MONTH                  0
# YEAR                   0
# dtype: int64

# %%
df.groupby('DISAGMOT')['VALUE'].sum().sort_values(ascending=False)
# Out:
# DISAGMOT
# 5    38514243452
# 6     5952242493
# 1     4369835065
# 7     3420220739
# 3     3155663726
# 8     2537783453
# 9      171736279
# 4        1249061
# Name: VALUE, dtype: int64

# %%
df.groupby('DISAGMOT')['VALUE'].sum().plot(kind='bar', title='Freight Value by Mode')
plt.ylabel('Total Value')
plt.xlabel('Transportation Mode')
plt.show()
